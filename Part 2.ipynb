# %% [markdown]
# # Part 2 ‐ Experiment and metrics design

# %% [markdown]
# The neighboring cities of Gotham and Metropolis have complementary circadian rhythms: on
# weekdays, Ultimate Gotham is most active at night, and Ultimate Metropolis is most active
# during the day. On weekends, there is reasonable activity in both cities.
# However, a toll bridge, with a two way toll, between the two cities causes driver partners to tend
# to be exclusive to each city. The Ultimate managers of city operations for the two cities have
# proposed an experiment to encourage driver partners to be available in both cities, by
# reimbursing all toll costs.

# %% [markdown]
#  1. What would you choose as the key measure of success of this experiment in
# encouraging driver partners to serve both cities, and why would you choose this metric?

# %% [markdown]
#  - Depending on what data is collected today.  Based on the information above, I'm assuming we have data showing whether a driver stays exclusive in their city or drives over to the neighbour city.
#
#  - I would choose the number of drivers/which city they're from.  So to measure success I would check if Metropolis partner drivers are going to Ultimate Gotham at night during weekdays.
# I would also check if Ultimate Gotham drirvers are going over to Ultimate Metropolis during the day on weekdays.
#
#  - Generaly speaking, we should see an increase in the number of partner drivers in both cities at the most active hours.
#
# - I don't expect to see an increase on weekeds since both cities are active.
#
# - I would also track the number of reiburments and when they occured to identify that partner drives are working in a the neighbour city.

# %% [markdown]
# 2.  Describe a practical experiment you would design to compare the effectiveness of the
# proposed change in relation to the key measure of success. Please provide details on:
#
# a. How will you implement the experiment
#  - Collect data about the partner drivers, which drivers are driving where today (before the expirement begins)
#  - The dates/time of drivers from partner city cross over - possibly track the toll charges for drivers, identify if the toll charges are for drivers.
#  - once the expirement begins continue to track the data mentioned above along with the reimbursments for drivers.

# %% [markdown]
# b. what statistical test(s) you will conduct to verify the significance of the
# observation
#  - A histogram displaying the number of drivers from neibouring cities on weekdays (one of evenings and one for day time)
#  - calculate and visualize the increase/decrease in drivers
#  - calculate the percentage change of drivers are different times of the day

# %% [markdown]
# c. how you would interpret the results and provide recommendations to the city
# operations team along with any caveats.
#
#  - If there is an increase in drivers/toll reimbursments for the times where each city is most active I believe the expirement is successful.
#  - I would check the percentage increase - and compare it to how much of an increase the city was expecting.
